# %%
import pandas as pd
import matplotlib.pyplot as plt
import geopandas as gpd
from mpl_toolkits.basemap import Basemap

import plotly.express as px

# %%
data = pd.read_excel('C:/Users/ampon/Desktop/PYTHON/mobile.xlsx')
data
# Out:
#                    Timestamp                Session_Name  Unnamed: 2  \
# 0    2024-07-01T15:39:57.000  PDCAF-01072024-34-mobile-2         NaN
# 1    2024-07-01T15:40:07.000  PDCAF-01072024-34-mobile-2         NaN
# 2    2024-07-01T15:40:17.000  PDCAF-01072024-34-mobile-2         NaN
# 3    2024-07-01T15:40:27.000  PDCAF-01072024-34-mobile-2         NaN
# 4    2024-07-01T15:40:31.000  PDCAF-01072024-34-mobile-2         NaN
# ..                       ...                         ...         ...
# 771  2024-07-01T15:53:30.000  PDCAF-01072024-34-mobile-2         NaN
# 772  2024-07-01T15:53:31.000  PDCAF-01072024-34-mobile-2         NaN
# 773  2024-07-01T15:53:32.000  PDCAF-01072024-34-mobile-2         NaN
# 774  2024-07-01T15:53:33.000  PDCAF-01072024-34-mobile-2         NaN
# 775  2024-07-01T15:53:34.000  PDCAF-01072024-34-mobile-2         NaN
#
#      Latitude  Longitude  T/°F   PM1  PM10  PM2.5    RH
# 0    6.615827  -1.620580  93.0  35.0  58.0   39.0  63.0
# 1    6.615823  -1.620553  93.0  34.0  57.0   38.0  63.0
# 2    6.615803  -1.620448  93.0  32.0  51.0   35.0  63.0
# 3    6.615763  -1.620364  93.0  36.0  61.0   40.0  64.0
# 4    6.615750  -1.620338  93.0  33.0  54.0   36.0  64.0
# ..        ...        ...   ...   ...   ...    ...   ...
# 771  6.612494  -1.620849  99.0  22.0  29.0   24.0  52.0
# 772  6.612490  -1.620855  99.0  21.0  27.0   23.0  52.0
# 773  6.612487  -1.620860  99.0  22.0  29.0   24.0  52.0
# 774  6.612484  -1.620864  99.0  22.0  29.0   24.0  52.0
# 775  6.612483  -1.620866  99.0  22.0  29.0   24.0  52.0
#
# [776 rows x 10 columns]

# %%
print(data['PM1'].isna().sum())  # Check the number of NaN values
# Out:
# 10

# %%
import pandas as pd
import plotly.express as px


# 1. Drop rows with missing PM1 values
data = data.dropna(subset=['PM1'])

# 2. Alternatively, fill missing PM1 values with the mean

data.loc[:, 'PM1'] = data['PM1'].fillna(data['PM1'].mean())


# Verify that there are no NaN values in 'PM1'
print("Number of NaN values in 'PM1':", data['PM1'].isna().sum())
# Out:
# Number of NaN values in 'PM1': 0

# %%
data['PM1'] = pd.to_numeric(data['PM1'], errors='coerce')

# After cleaning, you might want to drop any new NaNs introduced by non-numeric conversion
data = data.dropna(subset=['PM1'])

# %%
fig = px.scatter_mapbox(
    data,
    lon=data['Longitude'],
    lat=data['Latitude'],
    zoom=8,
    color=data['PM1'],
    size=data['PM1'],
    width=1200,
    height=900,
    title='PM1 DISTRIBUTION'
)

fig.update_layout(mapbox_style="open-street-map")
fig.update_layout(margin={"r": 0, "t": 50, "l": 0, "b": 10})
fig.show()

# %%
# Load the data
data = pd.read_excel('C:/Users/ampon/Desktop/PYTHON/mobile.xlsx')
data
# Extract relevant columns
lats = data['Latitude']
lons = data['Longitude']
pm1 = data['PM1']  # Replace with the column name for PM1

# # Create a scatter plot
plt.figure(figsize=(10, 8))
plt.scatter(lons, lats, c=pm1, cmap='viridis', s=50, alpha=0.7)
plt.colorbar(label='PM1 Levels')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.title('Spatial Distribution of PM1')
plt.grid(True)
plt.show()

# %%
# Drop rows with NaN values in Latitude, Longitude, or PM1 columns
data_cleaned = data.dropna(subset=['Latitude', 'Longitude', 'PM1'])

# %%
import folium
from folium.plugins import HeatMap

# Initialize a map
m = folium.Map(location=[data_cleaned['Latitude'].mean(), data_cleaned['Longitude'].mean()], zoom_start=10)

# # Add PM1 data as a heatmap
heat_data = [[row['Latitude'], row['Longitude'], row['PM1']] for index, row in data_cleaned.iterrows()]
HeatMap(heat_data, radius=10).add_to(m)

# # Save or display the map
m.save('pm1_distribution_map.html')
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8c3b87b373f48620f3407914401b71bd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8c3b87b373f48620f3407914401b71bd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8c3b87b373f48620f3407914401b71bd = L.map(
#                 &quot;map_8c3b87b373f48620f3407914401b71bd&quot;,
#                 {
#                     center: [6.613702959921671, -1.6209559838120104],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;maxBounds&quot;: null,
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_685622bb14130386a7bdbbf4fa925ed6 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_685622bb14130386a7bdbbf4fa925ed6.addTo(map_8c3b87b373f48620f3407914401b71bd);
#
#
#             var heat_map_185d34330374638f7dad2b3308fbc447 = L.heatLayer(
#                 [[6.6158275, -1.6205804, 35.0], [6.615823, -1.6205528, 34.0], [6.6158029, -1.6204482, 32.0], [6.6157635, -1.6203638, 36.0], [6.6157497, -1.6203379, 33.0], [6.6157458, -1.6203317, 28.0], [6.6157458, -1.6203317, 28.0], [6.6157341, -1.6203185, 28.0], [6.6157276, -1.6203119, 23.0], [6.6157276, -1.6203119, 23.0], [6.6157155, -1.6203011, 23.0], [6.6157126, -1.6202984, 23.0], [6.6157126, -1.6202984, 23.0], [6.6157051, -1.6202982, 22.0], [6.6156982, -1.6203015, 23.0], [6.6156982, -1.6203015, 22.0], [6.615681, -1.6203059, 22.0], [6.6156723, -1.6203064, 23.0], [6.6156553, -1.620307, 23.0], [6.6156453, -1.6203064, 23.0], [6.6156034, -1.6202986, 23.0], [6.6155933, -1.6202985, 26.0], [6.6155933, -1.6202985, 23.0], [6.6155834, -1.6203005, 23.0], [6.6155637, -1.6203083, 23.0], [6.6155488, -1.6203133, 23.0], [6.6155488, -1.6203133, 23.0], [6.6155228, -1.6203248, 23.0], [6.6155094, -1.6203296, 21.0], [6.6155094, -1.6203296, 22.0], [6.6154877, -1.620337, 22.0], [6.6154877, -1.620337, 23.0], [6.6154794, -1.6203361, 23.0], [6.6154694, -1.6203338, 23.0], [6.6154462, -1.6203283, 23.0], [6.6154254, -1.6203218, 23.0], [6.6154201, -1.620319, 23.0], [6.6154201, -1.620319, 23.0], [6.6154041, -1.6203237, 23.0], [6.6153935, -1.6203298, 23.0], [6.6153694, -1.6203427, 23.0], [6.6153585, -1.6203459, 26.0], [6.6153585, -1.6203459, 23.0], [6.61534, -1.6203556, 26.0], [6.6153285, -1.6203596, 26.0], [6.6152977, -1.6203667, 26.0], [6.6152845, -1.6203737, 26.0], [6.6152845, -1.6203737, 26.0], [6.6152793, -1.6203888, 26.0], [6.6152682, -1.6203835, 24.0], [6.6152371, -1.6203854, 26.0], [6.6152371, -1.6203854, 26.0], [6.6152213, -1.6203863, 28.0], [6.6152034, -1.620391, 26.0], [6.6152034, -1.620391, 23.0], [6.615197, -1.6203955, 23.0], [6.6151769, -1.6204021, 26.0], [6.6151669, -1.6204078, 26.0], [6.6151669, -1.6204078, 26.0], [6.6151512, -1.6204198, 23.0], [6.615143, -1.6204284, 23.0], [6.615143, -1.6204284, 23.0], [6.6151493, -1.620434, 26.0], [6.6151526, -1.6204351, 30.0], [6.6151431, -1.6204366, 30.0], [6.6151389, -1.6204283, 28.0], [6.6151324, -1.6204265, 26.0], [6.6151245, -1.6204289, 24.0], [6.6151131, -1.6204356, 23.0], [6.6151131, -1.6204356, 23.0], [6.6150911, -1.6204517, 22.0], [6.6150785, -1.6204573, 22.0], [6.6150785, -1.6204573, 21.0], [6.6150585, -1.6204627, 21.0], [6.6150469, -1.6204641, 21.0], [6.6150217, -1.6204733, 21.0], [6.6150217, -1.6204733, 21.0], [6.6150121, -1.6204784, 22.0], [6.614999, -1.620487, 23.0], [6.6149921, -1.6204922, 23.0], [6.6149921, -1.6204922, 23.0], [6.6149742, -1.620512, 23.0], [6.6149678, -1.6205223, 23.0], [6.6149678, -1.6205223, 23.0], [6.6149424, -1.6205266, 23.0], [6.614931, -1.6205279, 23.0], [6.614931, -1.6205279, 23.0], [6.6149069, -1.6205354, 23.0], [6.6148962, -1.6205399, 23.0], [6.6148962, -1.6205399, 23.0], [6.6148771, -1.6205482, 26.0], [6.6148652, -1.6205533, 23.0], [6.6148379, -1.6205677, 23.0], [6.6148248, -1.6205749, 23.0], [6.6148124, -1.6205796, 23.0], [6.6148021, -1.6205848, 22.0], [6.6147929, -1.6205884, 22.0], [6.6147929, -1.6205884, 22.0], [6.6147712, -1.6205908, 23.0], [6.6147573, -1.6205933, 22.0], [6.6147413, -1.6206048, 22.0], [6.6147339, -1.6206091, 23.0], [6.6147258, -1.6206139, 22.0], [6.6147146, -1.6206146, 22.0], [6.6147013, -1.6206122, 22.0], [6.6146794, -1.6206142, 21.0], [6.6146671, -1.6206181, 23.0], [6.6146671, -1.6206181, 26.0], [6.6146461, -1.620625, 23.0], [6.6146461, -1.620625, 23.0], [6.6146353, -1.6206302, 23.0], [6.6146145, -1.6206461, 23.0], [6.6146047, -1.6206523, 23.0], [6.6146047, -1.6206523, 23.0], [6.6145885, -1.6206644, 23.0], [6.6145792, -1.6206699, 23.0], [6.6145629, -1.6206821, 22.0], [6.6145585, -1.6206879, 22.0], [6.6145585, -1.6206879, 23.0], [6.6145442, -1.6206971, 23.0], [6.6145364, -1.6206987, 23.0], [6.6145364, -1.6206987, 23.0], [6.6145286, -1.6207, 23.0], [6.6145247, -1.6207046, 23.0], [6.6145

# %%
import pandas as pd
import plotly.express as px

# Drop rows with missing values in Latitude, Longitude, or PM1
cleaned_data = data.dropna(subset=["Latitude", "Longitude", "PM1"])

# Create scatter map with OSM as the base
fig = px.scatter_mapbox(cleaned_data, lat="Latitude", lon="Longitude", color="PM1",
                        size="PM1", color_continuous_scale=px.colors.sequential.Viridis,
                        zoom=10, mapbox_style="open-street-map")

# Show map
fig.show()
